# %% [markdown]
# **Q1. What is the purpose of Python's OOP?**

# %% [markdown]
# **Solutioon:-** OOPs(Object Oriented Programming) in Python is a programming approach that focuses on using objects and classes as other general programming languages. Objects can considered analogous to any real-world entities. Python allows developers to develop applications using the OOPs concept which **focus majorily on code reusability.**

# %% [markdown]
# **Q2. Where does an inheritance search look for an attribute?**

# %% [markdown]
# **Solution:-** In Python, inheritance happens when an object is qualified, and involves searching an attribute definition tree (one or more namespaces) attribute where object is an instance or class object, Python searches the namespace tree at and above object , for the first attribute it can find.
#
# Three ways namespace trees are constructed:
#
# **Instance attributes** are generated by assignments to self attributes in methods.
#
# **Class attributes** are created by statements (assignments) in class statements.
#
# **Superclass links** are made by listing classes in parentheses in a class statement header.

# %% [markdown]
# **Q3. How do you distinguish between a class object and an instance object?**

# %% [markdown]
# **Solution:-** The **class = the blue print**. The **Object** is an actual thing that is built based on the **'blue print'** (like the house). An **instance** is a **virtual copy** (but not a real copy) of the object.
#
# An **Object** is created from a Class, like a house is created from a blueprint. We could use a blueprint of a 3 bedroom home to build multiple 3 bedroom homes - 1 blueprint to create multiple 3 bedroom homes. This is what happens with a Class. You can create multiple Objects from your single Class because Class is just the blueprint for creating Objects of the same type.
#
# So we've taken our blueprint (Class), and created multiple 3 bedroom homes (Objects), but how do we refer to one particular home (Object) we've built? We refer to a particular Object as an Instance. If I were to paint the frontdoor of one of the homes, I would be painting the door of a particular Instance of the Objects (home) created from my Class (blueprint).

# %% [markdown]
# **Q4. What makes the first argument in a class’s method function special?**

# %% [markdown]
# **Solution:-** The first method __init__() is a special method, which is called class constructor or initialization method that Python calls when you create a new instance of this class. It contain all the attributes of the whole function.

# %% [markdown]
# **Q5. What is the purpose of the (__init__) method?**

# %% [markdown]
# **Solution:-** "__init__" is a reseved method in python classes. It is called as a constructor in object oriented terminology. This method is called when an object is created from a class and it allows the class to initialize the attributes of the class.
#
# When you make a new class in Python the first method we make is the __init__ method. The __init__ method allows you to accept arguments to your class.
#
# The __init__ method allows to assign initial values to various attributes on class instances.

# %%
class Purpose:
    
    #Creating The init method
    def __init__(self,Student,Course,Batch,Specilization):
        self.Student = Student
        self.Course = Course
        self.Batch = Batch
        self.Specilization = Specilization

vit = Purpose(100, 4, 2022, 5)
 
print("VIT has: ",vit.Specilization,"No. of Specilizations, ", vit.Batch, "in Batchs,", vit.Course, "No. of Courses,", vit.Student, "No. of students")
# Out:
# VIT has:  5 No. of Specilizations,  2022 in Batchs, 4 No. of Courses, 100 No. of students

# %% [markdown]
# **Q6. What is the process for creating a class instance?**

# %% [markdown]
# **Solutioon:-** To create instances of a class, we call the class using class name and pass the arguments in __init__ method. In shown in below example.

# %%
class Employee:
    empCount = 0

    def __init__(self, name, salary):
            self.name = name
            self.salary = salary
        
            Employee.empCount += 1
   
    def displayCount(self):
         print ("Total Employee %d" % Employee.empCount)

# %%
#Creating The Class Instance
emp1 = Employee("Zara", 2000)

# %% [markdown]
# **Q7. What is the process for creating a class?**

# %% [markdown]
# **Solution:-** The class statement creates a new class definition.
#
# - The class has a documentation string, which can be accessed via ClassName.__doc__.
# - The class_suite consists of all the component statements defining class members, data attributes and functions.

# %%
class Person:
    "This is a person class"
    age = 10

    def greet(self):
        print('Hello')

print("Person's age: ", Person.age)

print("Person's greeting: ",Person.greet)

print("Person's class: ",Person.__doc__)

Gourav= Person()
# Out:
# Person's age:  10
# Person's greeting:  <function Person.greet at 0x0000021122D835E0>
# Person's class:  This is a person class

# %% [markdown]
# **Q8. How would you define the superclasses of a class?**

# %% [markdown]
# **Solution:-** A superclass is the class from which many subclasses are created. The subclasses inherit the characteristics of a superclass. The superclass is also known as the parent class or base class. The **super() function** is used to give access to methods and properties of a **parent or sibling** class to subclasses. The **super() function** returns an object that represents the **parent class.**

# %%
class Parent:
    
    def __init__(self, txt):
        self.message = txt

    def printmessage(self):
         print(self.message)

class Child(Parent):
    
    def __init__(self, txt):
        super().__init__(txt)

x = Child("Hello, and welcome!")

x.printmessage()
# Out:
# Hello, and welcome!
